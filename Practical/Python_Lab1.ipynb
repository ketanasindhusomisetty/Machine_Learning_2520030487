# %% [markdown]
# <a href="https://colab.research.google.com/github/ketanasindhusomisetty/Machine_Learning_2520030487/blob/main/Practical/Python_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Write a Python program to declare variables of type int, float, string, and boolean, and display their values along with their data types.
x = 5
y = 3.14
name = "CGPA"
is_placed = True

print(x)
print(type(x))
print(y)
print(type(y))
print(name)
print(type(name))
print(is_placed)
print(type(is_placed))
# Out:
# 5
# <class 'int'>
# 3.14
# <class 'float'>
# CGPA
# <class 'str'>
# True
# <class 'bool'>

# %%
#Write a program to check the data type of different variables using the type() function.
age = 25
name = "Alex"
is_student = True

print(type(age))
print(type(name))
print(type(is_student))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>

# %%
#Modify the values of the variables and observe how their data types change.
